# %%
import pandas as pd

# %%
pedidos = pd.read_csv("Todos pedido.csv")
pedidos["Package ID"] = pedidos["Package ID"].str.replace("\t","").
pedidos["Package ID"] = pedidos["Package ID"].str.replace(" ","")

# %%
pedidos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6347 entries, 0 to 6346
# Data columns (total 58 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Order ID                        6347 non-null   int64
#  1   Package ID                      6347 non-null   object
#  2   Order Status                    6347 non-null   object
#  3   Order Substatus                 6347 non-null   object
#  4   Cancelation/Return Type         1695 non-null   object
#  5   Normal or Pre-order             6129 non-null   object
#  6   SKU ID                          6347 non-null   int64
#  7   Seller SKU                      6347 non-null   object
#  8   Product Name                    6347 non-null   object
#  9   Variation                       6347 non-null   object
#  10  Product Category                6347 non-null   object
#  11  Quantity                        6347 non-null   int64
# ...

# %%
pedidos.head(1)
# Out:
#              Order ID Package ID Order Status Order Substatus  \
# 0  582842497552581968               Cancelado       Cancelado
#
#   Cancelation/Return Type Normal or Pre-order               SKU ID  \
# 0                  Cancel              Normal  1733928767378851190
#
#                Seller SKU                                       Product Name  \
# 0  PEBCN-BBML 12-24-12-24  Kit Pares de Meias 3D com Chocalho Menino Anti...
#
#                   Variation  ...   Neighborhood  House Name or Number  \
# 0  1 par aleatório, 1 Pares  ...  *************                  ****
#
#         City State Country     Zipcode  \
# 0  São Paulo    SP  Brasil  ********\t
#
#                                 Shipping Information Invoice Status  \
# 0  C***** q***** q*****\r\n(+55)119******12\r\n**...            NaN
#
#   Buyer Message Seller Note
# 0           NaN         NaN
#
# [1 rows x 58 columns]

# %%
pedidos["Package ID"] = pedidos["Package ID"].str.replace("\t","")

# %%
pedidos.head(2)
# Out:
#              Order ID           Package ID Order Status Order Substatus  \
# 0  582842497552581968                         Cancelado       Cancelado
# 1  582842361247204456  1187749005812008040      Enviado        Entregue
#
#   Cancelation/Return Type Normal or Pre-order               SKU ID  \
# 0                  Cancel              Normal  1733928767378851190
# 1                     NaN              Normal  1734385029151425910
#
#                Seller SKU                                       Product Name  \
# 0  PEBCN-BBML 12-24-12-24  Kit Pares de Meias 3D com Chocalho Menino Anti...
# 1                21011-41     Chinelo Masculino Esportivo Casual Confortável
#
#                   Variation  ...   Neighborhood  House Name or Number  \
# 0  1 par aleatório, 1 Pares  ...  *************                  ****
# 1    Preto/cáqui, 41CH-39BR  ...    Três Marias                  casa
#
#           City State Country     Zipcode  \
# 0    São Paulo    SP  Brasil  ********\t
# ...
